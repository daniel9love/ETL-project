# %%
import os 
import pandas as pd

# %%
path ="Time_Series_19-covid-Confirmed Cases.csv"

covid_df = pd.read_csv(path)
covid_df.head()
# Out:
#   Province/State  Country/Region      Lat      Long  1/22/2020  1/23/2020  \
# 0          Anhui  Mainland China  31.8257  117.2264          1          9
# 1        Beijing  Mainland China  40.1824  116.4142         14         22
# 2      Chongqing  Mainland China  30.0572  107.8740          6          9
# 3         Fujian  Mainland China  26.0789  117.9874          1          5
# 4          Gansu  Mainland China  36.0611  103.8343          0          2
#
#    1/24/2020  1/25/2020  1/26/2020  1/27/2020  ...  2/26/2020  2/27/2020  \
# 0         15         39         60         70  ...        989        989
# 1         36         41         68         80  ...        400        410
# 2         27         57         75        110  ...        576        576
# 3         10         18         35         59  ...        294        296
# 4          2          4          7         14  ...         91         91
#
#    2/28/2020  2/29/2020  3/1/2020  3/2/2020  3/3/2020  3/4/2020  3/5/2020  \
# ...

# %%
# List of confirmed cases columns
column_list = covid_df.columns[4:49]
jan = covid_df.columns[4:14]
feb = covid_df.columns[15:43]
march = covid_df.columns[44:49]

# Sum of all confirmed cases
covid_df['Jan Confirmed Cases'] = covid_df[jan].sum(axis=1)
covid_df['Feb Confirmed Cases'] = covid_df[feb].sum(axis=1)
covid_df['March Confirmed Cases'] = covid_df[march].sum(axis=1)
covid_df['Total Confirmed Cases'] = covid_df[column_list].sum(axis=1)

covid_cleaned_df = covid_df[['Province/State','Country/Region', 'Lat','Long',
                             'Jan Confirmed Cases', 'Feb Confirmed Cases', 
                             'March Confirmed Cases','Total Confirmed Cases']]
covid_cleaned_df
# Out:
#         Province/State  Country/Region      Lat      Long  \
# 0                Anhui  Mainland China  31.8257  117.2264
# 1              Beijing  Mainland China  40.1824  116.4142
# 2            Chongqing  Mainland China  30.0572  107.8740
# 3               Fujian  Mainland China  26.0789  117.9874
# 4                Gansu  Mainland China  36.0611  103.8343
# ..                 ...             ...      ...       ...
# 194  Ramsey County, MN              US  44.9964  -93.0616
# 195  Washoe County, NV              US  40.5608 -119.6035
# 196   Wayne County, PA              US  41.6739  -75.2479
# 197    Yolo County, CA              US  38.7646 -121.9018
# 198                NaN    Vatican City  41.9029   12.4534
#
#      Jan Confirmed Cases  Feb Confirmed Cases  March Confirmed Cases  \
# 0                    889                23691                   4950
# 1                    716                 9800                   2086
# ...

# %%
# Renaming Countries
covid_cleaned_df.replace('Mainland China', 'China', inplace=True)
covid_cleaned_df.replace('UK', 'United Kingdom', inplace=True)
covid_cleaned_df.replace('US', 'United States', inplace=True)
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4278: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# Dropping unneeded columns
covid19_cleaned = covid_cleaned_df[['Country/Region','Jan Confirmed Cases', 
                    'Feb Confirmed Cases', 'March Confirmed Cases','Total Confirmed Cases']]

# Grouping counts by country, resetting index, renaming columns
covid19_cleaned_df = covid19_cleaned.groupby(['Country/Region']).sum()
covid19_cleaned_df = covid19_cleaned_df.reset_index()
covid19_cleaned_df = covid19_cleaned_df.rename(columns = {'Country/Region':'Country'})
 
covid19_cleaned_df
# Out:
#                  Country  Jan Confirmed Cases  Feb Confirmed Cases  \
# 0            Afghanistan                    0                    6
# 1                Algeria                    0                    5
# 2                Andorra                    0                    0
# 3              Argentina                    0                    0
# 4                Armenia                    0                    0
# ..                   ...                  ...                  ...
# 94  United Arab Emirates                   12                  264
# 95        United Kingdom                    2                  240
# 96         United States                   38                  710
# 97          Vatican City                    0                    0
# 98               Vietnam                   18                  392
#
#     March Confirmed Cases  Total Confirmed Cases
# 0                       5                     12
# 1                      49                     55
# ...

# %%
# Save df to a csv file
covid19_cleaned_df.to_csv ('covid19_cleaned', index = False, header = True)

# %%
# Finding min, max and avg latitude
min_lat = covid_cleaned_df['Lat'].min()
max_lat = covid_cleaned_df['Lat'].max()
avg_lat = covid_cleaned_df['Lat'].mean()

print(f' Min Lat: {round(min_lat,2)}')
print(f' Max Lat: {round(max_lat,2)}')
print(f' Avg Lat: {round(avg_lat,2)}')
# Out:
#  Min Lat: -41.45
#  Max Lat: 64.96
#  Avg Lat: 31.84

# %%
# Calculate total confirmed cases
total_confirmed = covid_cleaned_df['Total Confirmed Cases'].sum()
print(f'Total Confirmed Cases: {total_confirmed}')
# Out:
# Total Confirmed Cases: 2276824

# %%
# Countries covid 19 has spread to
covid_spread = covid_cleaned_df.loc[(covid_cleaned_df["Country/Region"] != "Mainland China")]
covid_spread
# Out:
#         Province/State Country/Region      Lat      Long  Jan Confirmed Cases  \
# 31                 NaN       Thailand  15.0000  101.0000                   94
# 32                 NaN          Japan  36.0000  138.0000                   55
# 33                 NaN    South Korea  36.0000  128.0000                   36
# 34              Taiwan         Taiwan  23.7000  121.0000                   52
# 35     King County, WA             US  47.6062 -122.3321                   10
# ..                 ...            ...      ...       ...                  ...
# 194  Ramsey County, MN             US  44.9964  -93.0616                    0
# 195  Washoe County, NV             US  40.5608 -119.6035                    0
# 196   Wayne County, PA             US  41.6739  -75.2479                    0
# 197    Yolo County, CA             US  38.7646 -121.9018                    0
# 198                NaN   Vatican City  41.9029   12.4534                    0
#
# ...

# %%
# Calculating confirmed cases outside of China
total_spread = covid_spread['Total Confirmed Cases'].sum()
print(f'Total Confirmed Cases Outside China: {total_spread}')
# Out:
# Total Confirmed Cases Outside China: 126123

# %%
# Calculating confirmed cases in Northern and Southern hemisphere
covid_north_hemi = covid_spread.loc[(covid_spread["Lat"] > 0)]
covid_south_hemi = covid_spread.loc[(covid_spread["Lat"] < 0)]

north_covid =  covid_north_hemi['Total Confirmed Cases'].sum()
south_covid =  covid_south_hemi['Total Confirmed Cases'].sum()

print(f'Northern Hemisphere Confirmed Cases (Outside of China): {north_covid}')
print(f'Southern Hemisphere Confirmed Cases: {south_covid}')
# Out:
# Northern Hemisphere Confirmed Cases (Outside of China): 125259
# Southern Hemisphere Confirmed Cases: 864

# %%
country_list = covid19_cleaned_df['Country'].tolist()
country_list
# Out:
# ['Afghanistan',
#  'Algeria',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Belarus',
#  'Belgium',
#  'Bhutan',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'Estonia',
#  'Faroe Islands',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macau',
#  'Mainland China',
#  'Malaysia',
#  'Mexico',
#  'Monaco',
#  'Morocco',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Oman',
#  'Others',
#  'Pakistan',
# ...

# %%
len(country_list)
# Out:
# 99
